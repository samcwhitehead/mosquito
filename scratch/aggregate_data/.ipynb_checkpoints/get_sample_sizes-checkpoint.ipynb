# %% [markdown]
# # Check how much data of different types we have

# %% [markdown]
# ## Imports

# %%
import os

import numpy as np
import pandas as pd

# %% [markdown]
# ## Path info

# %%
# where to find stuff
root_path = '/media/sam/SamData/Mosquitoes/'
expr_log_path_full = os.path.join(root_path, 'experiment_log.xlsx')
# data_inventory_path_full = os.path.join(root_path, 'analysis', 'spike_detection_review_expr39-75.xlsx')
data_inventory_path_full = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTxmAxmcKGkBg4aunlsG7pGZsdzjI8id-0l8wpZZxjUWkeiAHSOXCUW-6aUR5gztOjtzCrvGOqaxUtl/pubhtml?gid=0&single=true'

# %% [markdown]
# ## Which data files do we think are usable?

# %%
# Files that were previously identified as good in experiments 1-38 (from get_spike_rate_wbf_data.ipynb)
data_files_old = ['19.1', '19.2', '19.4', '19.5', '19.6',
              '22.0', '22.1', '22.2', '22.4', '22.5', '22.6', '22.7', '22.8', '22.9', '22.12',
              '23.0', '23.1', '23.2', '23.3', '23.4', '23.5', '23.6', 
              '24.7', '24.8', 
              '26.1', '26.2', '26.3', 
              '28.0', '28.1', '28.2', '28.5', '28.6', '28.8', '28.9', 
              '29.7', '29.8',
              '32.1',
              '37.0', '37.1', '37.2', '37.3',
              '38.8', '38.9', '38.10', '38.11', '38.14', '38.15',
              '15.1', '15.2', '15.3', '15.6', '15.8', '15.10',
              '16.0', '16.1', 
              '17.9',
              '18.0', '18.1', '27.5', '30.0', '30.1', '30.2', '31.3', '31.4', '31.5', '31.6',
              '33.0', '33.1', '33.3', '33.4', '33.5', '34.1', '34.4', '34.5', '34.7', '35.0', 
              '35.1', '36.0', '36.3', '36.4',
    ]

# convert these to tuples, i guess?
data_file_ids = [(int(f.split('.')[0]), int(f.split('.')[1])) for f in data_files_old]

# %%
# for experiments 39-current, I'm trying to keep a google sheet giving the quality/status of each trial:
#   https://docs.google.com/spreadsheets/d/1Ss7OxrC5hHUlTz6C7DVUP1ujM5IX8uHGOTLbFJS7a2k/edit?usp=sharing
# For convenience in reading that out, I've also downloaded a local copy at 'data_inventory_path_full'
# inventory_df = pd.read_excel(data_inventory_path_full)
inventory_df = pd.read_csv(data_inventory_path_full)

# let's assume that trials categorized as 'Good', 'Sort', or 'Reanalyze' are going to be usable
good_idx = inventory_df['Status'].isin(['Good', 'Sort', 'Reanalyze'])

# get the file ids for these trials
expr_nums_df = inventory_df['Experiment Number'][good_idx].str.split('_')
expr_nums_df = expr_nums_df.apply(lambda row: row[0])
expr_nums = expr_nums_df.values.tolist()

axo_nums = inventory_df['Axo Number'].values.tolist()

data_file_ids_new = [(int(en), int(an)) for en, an in zip(expr_nums, axo_nums)]

# combine
data_file_ids.extend(data_file_ids_new)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[18], line 5
#       1 # for experiments 39-current, I'm trying to keep a google sheet giving the quality/status of each trial:
#       2 #   https://docs.google.com/spreadsheets/d/1Ss7OxrC5hHUlTz6C7DVUP1ujM5IX8uHGOTLbFJS7a2k/edit?usp=sharing
#       3 # For convenience in reading that out, I've also downloaded a local copy at 'data_inventory_path_full'
#       4 # inventory_df = pd.read_excel(data_inventory_path_full)
# ----> 5 inventory_df = pd.read_csv(data_inventory_path_full)
#       7 # let's assume that trials categorized as 'Good', 'Sort', or 'Reanalyze' are going to be usable
#       8 good_idx = inventory_df['Status'].isin(['Good', 'Sort', 'Reanalyze'])
#
# File ~/Documents/code/mosquito/.pixi/envs/default/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/code/mosquito/.pixi/envs/default/lib/python3.12/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/Documents/code/mosquito/.pixi/envs/default/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/Documents/code/mosquito/.pixi/envs/default/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 669 fields in line 80, saw 4626

# %% [markdown]
# ## Get info for these data files

# %%
# load experiment log
log_df = pd.read_excel(expr_log_path_full)
log_df
# Out:
#              Day  Axo Num  Fly Num Sex     Species Target Muscle Type  \
# 0    01_20240316      NaN        1   F       Aedes                NaN
# 1    02_20240318      0.0        1   F       Aedes              power
# 2    02_20240318      1.0        1   F       Aedes              power
# 3    02_20240318      2.0        1   F       Aedes                 b1
# 4    02_20240318      3.0        1   F       Aedes                 b1
# ..           ...      ...      ...  ..         ...                ...
# 514  75_20250221      7.0        2   F  Drosophila           steering
# 515  75_20250221      8.0        3   F  Drosophila           steering
# 516  75_20250221      9.0        3   F  Drosophila           steering
# 517  75_20250221     10.0        4   F  Drosophila           steering
# 518  75_20250221     11.0        4   F  Drosophila           steering
#
#     Target Muscle Electrode Num  Video Count  \
# 0             NaN           NaN            4
# 1             NaN           NaN            3
# 2             NaN           NaN            3
# 3             NaN           NaN            0
# 4             NaN           NaN            4
# ..            ...           ...          ...
# 514       b1_None             2            1
# 515       b1_None             1            0
# 516       b1_None             2            0
# 517       b1_None             1            0
# 518       b1_None             2            0
#
#                                                  Notes
# 0                               No axoscope recordings
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 514                                Trying new position
# 515                                      Not very good
# 516                    New position but still not good
# 517  Also not very good. I think the electrode shif...
# 518   Moved a little. This location seems interesting?
#
# [519 rows x 10 columns]

# %%
# take just the rows for trials we think we can use
log_expr_nums = log_df['Day'].str.split('_').apply(lambda row: row[0]).astype(int).values
log_axo_nums = log_df['Axo Num'].fillna(value=0).astype(int).values

good_log_idx = np.zeros((log_expr_nums.size, ), dtype=bool)
for ith, (expr_num, axo_num) in enumerate(zip(log_expr_nums, log_axo_nums)):
    if (expr_num, axo_num) in data_file_ids:
        good_log_idx[ith] = True

# %%
good_log_df = log_df.loc[good_log_idx]
good_log_df
# Out:
#              Day  Axo Num  Fly Num Sex     Species Target Muscle Type  \
# 56   15_20240503      1.0        1   M       Aedes              power
# 57   15_20240503      2.0        1   M       Aedes              power
# 58   15_20240503      3.0        1   M       Aedes              power
# 61   15_20240503      6.0        3   M       Aedes              power
# 63   15_20240503      8.0        4   M       Aedes              power
# ..           ...      ...      ...  ..         ...                ...
# 499  73_20250216      4.0        3   F  Drosophila              power
# 500  73_20250216      5.0        3   F  Drosophila              power
# 509  75_20250221      2.0        1   F  Drosophila           steering
# 510  75_20250221      3.0        1   F  Drosophila           steering
# 512  75_20250221      5.0        2   F  Drosophila           steering
#
#     Target Muscle Electrode Num  Video Count  \
# 56            DLM             2            1
# 57            DVM             2            0
# 58            DVM             3            0
# 61            DLM             1            1
# 63            DVM             2            0
# ..            ...           ...          ...
# 499       DLM_DLM           1_1            0
# 500       DLM_DLM           1_2            0
# 509       b1_None             3            0
# 510       b1_None             3            0
# 512       b1_None             1            0
#
#                                                  Notes
# 56                                                 DLM
# 57                                                 DVM
# 58                                                 DVM
# 61                                                 DLM
# 63                                                 DVM
# ..                                                 ...
# 499  Tried normal placement. Nice recordings. 200X ...
# 500  Moved Target 2 posterior and deeper. I think e...
# 509                                      New placement
# 510  Same placement but switched to 300Hz lower cut...
# 512             Can't tell if this is bad or very good
#
# [184 rows x 10 columns]

# %% [markdown]
# ## Split multichannel rows so that we're counting each individually

# %%
# find multichannel rows
multichannel_idx = good_log_df['Target Muscle'].str.contains('_')

# make a new dataframe with two copies of each row
split_log_df = pd.concat(2*[good_log_df.loc[multichannel_idx]], ignore_index=True)
delete_idx = np.zeros((split_log_df.shape[0],), dtype=bool)

# loop over rows and take either the first or second Target Muscle/Electrode Num
for ith in np.arange(split_log_df.shape[0]):
    # get current target muscle and electrode nums
    target_muscle = split_log_df['Target Muscle'].loc[ith]
    electrode_num = split_log_df['Electrode Num'].loc[ith]

    if ith < (split_log_df.shape[0]/2):
        target_muscle_new = target_muscle.split('_')[0]
        try:
            electrode_num_new = str(electrode_num).split('_')[0]
        except IndexError:
            electrode_num_new = 'None'
        
    elif ith >= (split_log_df.shape[0]/2):
        target_muscle_new = target_muscle.split('_')[1]
        try:
            electrode_num_new = str(electrode_num).split('_')[1]
        except IndexError:
            electrode_num_new = 'None'

    # delete row if it's actually a single recording
    if electrode_num_new.lower() == 'none':
        delete_idx[ith] = True
        
    split_log_df.loc[ith, 'Target Muscle'] = target_muscle_new
    split_log_df.loc[ith, 'Electrode Num'] = electrode_num_new

# remove rows that don't actually correspond to a recording
split_log_df = split_log_df.loc[~delete_idx]
split_log_df
# Out:
#              Day  Axo Num  Fly Num Sex     Species Target Muscle Type  \
# 0    55_20241007      0.0        1   F       Aedes              power
# 1    55_20241007      5.0        2   F       Aedes              power
# 2    55_20241007      6.0        3   M       Aedes              power
# 3    55_20241007      7.0        4   F       Aedes           steering
# 4    55_20241007      8.0        4   F       Aedes           steering
# ..           ...      ...      ...  ..         ...                ...
# 144  73_20250216      1.0        1   M  Drosophila              power
# 145  73_20250216      2.0        2   F  Drosophila              power
# 146  73_20250216      3.0        2   F  Drosophila              power
# 147  73_20250216      4.0        3   F  Drosophila              power
# 148  73_20250216      5.0        3   F  Drosophila              power
#
#     Target Muscle Electrode Num  Video Count  \
# 0             DVM             1            1
# 1             DLM             2            1
# 2             DLM             1            1
# 3              b1             1            1
# 4              b3             2            1
# ..            ...           ...          ...
# 144           DLM             2            0
# 145           DLM             1            0
# 146           DLM             2            0
# 147           DLM             1            0
# 148           DLM             2            0
#
#                                                  Notes
# 0                                Overlapping units hit
# 1          DLM placement (EMG2) same as previous trial
# 2                             Lots of overlap in units
# 3    Trying steering. Low cut freq to 100 Hz. Took ...
# 4    Didn't move EMG2 electrode (b1? B2?) Tried to ...
# ..                                                 ...
# 144  Reduced Target 1 gain to 200X. Tried to just m...
# 145  Target 1 has another small unit, but might be ...
# 146  3 distinguishable units but maybe weak flight....
# 147  Tried normal placement. Nice recordings. 200X ...
# 148  Moved Target 2 posterior and deeper. I think e...
#
# [145 rows x 10 columns]

# %%
# merge this with the non-multichannel rows
good_log_df = pd.concat([good_log_df.loc[~multichannel_idx], split_log_df], ignore_index=True)

# %% [markdown]
# ## Get info on species, muscle target, and electrode number

# %%
# make a new 'Fly ID' column that combines experiment and fly number
fly_id = good_log_df['Day'] + '_' + good_log_df['Fly Num'].astype(str)

if 'Fly ID' not in good_log_df.columns:
    good_log_df.insert(len(good_log_df.columns), 'Fly ID', fly_id)

# %%
# try groupby.count
good_log_df_group = good_log_df.groupby(['Species', 'Sex', 'Target Muscle', 'Fly ID']).count()
good_log_df_group
# Out:
#                                             Day  Axo Num  Fly Num  \
# Species    Sex Target Muscle Fly ID
# Aedes      F   DLM           16_20240506_1    1        1        1
#                              19_20240510_1    1        1        1
#                              19_20240510_3    1        1        1
#                              22_20240516_2    1        1        1
#                              23_20240517_1    2        2        2
# ...                                         ...      ...      ...
# Drosophila M   DVM           71_20250213_2    2        2        2
#                              71_20250213_3    2        2        2
#                              72_20250214_1    1        1        1
#                              72_20250214_2    1        1        1
#                              73_20250216_1    1        1        1
#
#                                             Target Muscle Type  Electrode Num  \
# Species    Sex Target Muscle Fly ID
# Aedes      F   DLM           16_20240506_1                   1              1
#                              19_20240510_1                   1              1
#                              19_20240510_3                   1              1
#                              22_20240516_2                   1              1
#                              23_20240517_1                   2              2
# ...                                                        ...            ...
# Drosophila M   DVM           71_20250213_2                   2              2
#                              71_20250213_3                   2              2
#                              72_20250214_1                   1              1
#                              72_20250214_2                   1              1
#                              73_20250216_1                   1              1
#
#                                             Video Count  Notes
# Species    Sex Target Muscle Fly ID
# Aedes      F   DLM           16_20240506_1            1      1
#                              19_20240510_1            1      1
#                              19_20240510_3            1      1
#                              22_20240516_2            1      0
#                              23_20240517_1            2      2
# ...                                                 ...    ...
# Drosophila M   DVM           71_20250213_2            2      2
#                              71_20250213_3            2      2
#                              72_20250214_1            1      1
#                              72_20250214_2            1      1
#                              73_20250216_1            1      1
#
# [123 rows x 7 columns]

# %%
# how many unique fly IDs do we have then?
good_log_df_group.groupby(['Species', 'Sex', 'Target Muscle']).count()
# Out:
#                               Day  Axo Num  Fly Num  Target Muscle Type  \
# Species    Sex Target Muscle
# Aedes      F   DLM             20       20       20                  20
#                DVM             22       22       22                  22
#                b1               8        8        8                   8
#                b2               9        9        9                   9
#                b3               1        1        1                   1
#                hg1              1        1        1                   1
#            M   DLM              8        8        8                   8
#                DVM              6        6        6                   6
# Drosophila F   DLM             18       18       18                  18
#                DVM             10       10       10                  10
#                None             1        1        1                   1
#                b1               2        2        2                   2
#            M   ?                1        1        1                   1
#                DLM             10       10       10                  10
#                DVM              6        6        6                   6
#
#                               Electrode Num  Video Count  Notes
# Species    Sex Target Muscle
# Aedes      F   DLM                       20           20     20
#                DVM                       22           22     22
#                b1                         8            8      8
#                b2                         9            9      9
#                b3                         1            1      1
#                hg1                        1            1      1
#            M   DLM                        8            8      8
#                DVM                        6            6      6
# Drosophila F   DLM                       18           18     18
#                DVM                       10           10     10
#                None                       1            1      1
#                b1                         2            2      2
#            M   ?                          1            1      1
#                DLM                       10           10     10
#                DVM                        6            6      6

# %%
# np.savetxt('temp_log_idx.csv', good_log_idx, delimiter=',', fmt='%d')
