# %% [markdown]
# # First pass look for differences in male/female Aedes b1

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
import cv2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.signal import find_peaks, medfilt
from scipy.interpolate import interp1d, UnivariateSpline
from scipy.stats import zscore

from mosquito.process_abf import load_processed_data, estimate_spike_rate, save_processed_data
from mosquito.util import idx_by_thresh, my_adjust_axes, hampel, set_plot_params, my_add_scalebar

# %% [markdown]
# ## Params

# %%
# plt.style.use('dark_background')
plt.style.use('default')

plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=16)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)    # fontsize for x tick labels
plt.rc('ytick', labelsize=14)    # fontsize for y tick labels

plot_type = 'poster'  # 'paper' or 'powerpoint' or 'poster
plot_params = set_plot_params(plot_type=plot_type)

# %% [markdown]
# ## Helper functions

# %%
def plot_spike_rate(ax, data_folder, axo_num, sex, sex_color_flag=True):
    """
    Simple function to make it easier to plot multiple spike rates
    
    """
    # load data 
    data = load_processed_data(data_folder, axo_num)
    if sex_color_flag and (sex == 'F'):
        color = 'lightskyblue'
    elif sex_color_flag and (sex == 'M'):
        color = 'coral'
    else:
        color = 'w'
        
    # plot spike rate
    ax.plot(data['time'], data['spike_rate'], color=color)

    return ax

# %% [markdown]
# ## Load data

# %%
# Which data files to look at
data_folders = ['82_20250307', '83_20250310']
axo_nums = [4 , 2]
sexes = ['F', 'M']

# %%
# make plots showign comparison
fig, ax = plt.subplots(figsize=(12,4))

for ith, (data_folder, axo_num) in enumerate(zip(data_folders, axo_nums)):
    plot_spike_rate(ax, data_folder, axo_num, sexes[ith])
